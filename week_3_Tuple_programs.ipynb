# %%
#example
coordinates=(10.7,2.4,3.3)
print("Tuple:",coordinates)
# Out:
# Tuple: (10.7, 2.4, 3.3)

# %%
#access by index to print 1st element
fruit=("apple","banana","orange")
print("First fruit:",fruit[0])
# Out:
# First fruit: apple

# %%
#access by index to print last element
fruit=("apple","banana","orange")
print("last fruit:",fruit[-1])
# Out:
# last fruit: orange

# %%
#tuple unpacking
(x,y,z)=t
print("Unpacked:x={x},y={y},z={z}")
# Out:
# Unpacked:x={x},y={y},z={z}

# %%
#create a tuple of 4 elements and print it
tuple=(1,2,3,4)
print("Original tuple:",tuple)
# Out:
# Original tuple: (1, 2, 3, 4)

# %%
#print second and third element of tuple (10,20,30,40)
tuple=(10,20,30,40)
print("second element:",tuple[1])
print("third element:",tuple[2])
# Out:
# second element: 20
# third element: 30

# %%
#Unpack tuple (5,10,15) into variables and print 
t=(5,10,15)
a,b,c=t
print("unpacked:",a,b,c)
# Out:
# unpacked: 5 10 15
