# %%
#1b.relational operators
a=int(input("enetr a:"))
b=int(input("enter b:"))
print(a>b)
print(a<b)
print(a==b)
print(a<=b)
print(a>=b)
print(a!=b)
# Out:
# enetr a: 10
# enter b: 20
# False
# True
# False
# True
# False
# True
