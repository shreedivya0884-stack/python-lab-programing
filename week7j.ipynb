# %%
words = ["Python", "Java", "C", "JavaScript"]

lengths = list(map(lambda x: len(x), words))

print("Words:", words)
print("Lengths:", lengths)
# Out:
# Words: ['Python', 'Java', 'C', 'JavaScript']
# Lengths: [6, 4, 1, 10]
