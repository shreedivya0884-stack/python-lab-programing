# %%
#dictionary example program
student={
    "name":"Pari",
    "age":19,
    "Subjects":["Maths","Physics"]
}
print("Dictionary:",student)
# Out:
# Dictionary: {'name': 'Pari', 'age': 19, 'Subjects': ['Maths', 'Physics']}

# %%
#create an dictionary of employee details(id,name,department,salary)
employee={
    "name":"Pari",
    "id":1,
    "department name":"inforamation science",
    "salary":40000,
}
print("Dictionary of employee:",employee)
# Out:
# Dictionary of employee: {'name': 'Pari', 'id': 1, 'department name': 'inforamation science', 'salary': 40000}

# %%
# to add ubdates to student details
