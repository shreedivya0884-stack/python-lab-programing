# %%
#write apython program to read and display user input(name and age)
name=input("Enter name:")
age=int(input("Enter age:"))
print("Name:",name)
print("Age:",age)
# Out:
# Enter name: Parimala
# Enter age: 19
# Name: Parimala
# Age: 19
